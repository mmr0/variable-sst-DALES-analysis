# %% [markdown]
# # DALES plot SST

# %%
import xarray as xr

output_directory = '/scratch/fy29/mxr581/dales/run1'
filename = 'tskin.301.5.sinusoid_amp.0.25.wavelength.1024.nc'
file_path = f"{output_directory}/{filename}"
ds_run1 = xr.open_dataset(file_path)

output_directory = '/scratch/jk72/mxr581/dales/run2'
filename = 'tskin.301.5.sinusoid_amp.0.25.wavelength.512.nc'
file_path = f"{output_directory}/{filename}"
ds_run2 = xr.open_dataset(file_path)

output_directory = '/scratch/fy29/mxr581/dales/run3'
filename = 'tskin.301.5.sinusoid_amp.0.25.wavelength.256.nc'
file_path = f"{output_directory}/{filename}"
ds_run3 = xr.open_dataset(file_path)

# %%
ds_run1.tskin[-1,0,:].plot()
ds_run2.tskin[-1,0,:].plot()
ds_run3.tskin[-1,0,:].plot()

# %%
ds_run1
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:  (time: 481, y: 1024, x: 1024)
# Coordinates:
#   * time     (time) float64 4kB 0.0 540.0 1.08e+03 ... 2.587e+05 2.592e+05
#   * y        (y) int64 8kB 1 2 3 4 5 6 7 ... 1018 1019 1020 1021 1022 1023 1024
#   * x        (x) int64 8kB 1 2 3 4 5 6 7 ... 1018 1019 1020 1021 1022 1023 1024
# Data variables:
#     tskin    (time, y, x) float64 4GB ...
